# %%
import os
import sys
import urllib.request
import datetime
import time
import json
import pandas as pd

# %%
# [code1] url 접속을 요청하고 응답을 받아서 반환
def getRequestUrl(url):
    req = urllib.request.Request(url)  #매개변수로 받은 url에 대한 요청을 보낼 객체를 생성
    try:
        response = urllib.request.urlopen(req)  #요청 객체를 보내서 받은 응답 데이터를 response 객체에 저장

        #response 객체에 저장된 코드를 확인. 코드가 200이면 요청을 정상 처리한 것이므로 성공.
        # 메시지와 현재 시간을 파이썬 셸 창에 출력하고 응답을 utf-8 형식으로 디코딩하여 반환.
        if response.getcode() == 200:
            print("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')
    except Exception as e:
        print(e)
        print("[%s] Error for URL : %s" % (datetime.datetime.now(), url))
        return None

# %%
# [code2] 입국관광통계서비스의 오픈 API를 사용하여 데이터 요청 url을 만들고 [CODE 1]의 getRequestUrl(url)을 호출해서 받은 응답 데이터를 반환
ServiceKey = "TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D"

def getTourismStatsItem(yyyymm, national_code, ed_cd):
    service_url = "http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList"

    parameters = "?_type=json&serviceKey=" + ServiceKey #인증키
    parameters += "&YM=" + yyyymm
    parameters += "&NAT_CD=" + national_code
    parameters += "&ED_CD=" + ed_cd

    url = service_url + parameters
    print(url)   #액세스 거부 여부 확인용 출력
    retData = getRequestUrl(url) #[CODE 1]

    if (retData == None):
        return None
    else:
        return json.loads(retData)

# %%
# [code3] 수집 기간 동안 월 단위로 [CODE 2]의 getTourismStatsItem()을 호출해 받은 데이터를 리스트로 묶어 반환

def getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear):
    jsonResult = []
    result = []
    for year in range(nStartYear, nEndYear+1):
        for month in range(1, 13)
            yyyymm = "{0}{1:0>2}".format(str(year), str(month))
            jsonData = getTourismStatsItem(yyyymm, nat_cd, ed_cd) #[CODE 2]
            if (jsonData['response']['header']['resultMsg'] == 'OK'):
            #데이터가 없는 마지막 항목인 경우 ----------------------------
                if jsonData['response']['body']['items'] == '':
                    dataEND = "{0}{1:0>2}".format(str(year), str(month-1))
                    print("데이터 없음.... \n제공되는 통계 데이터는 %s년 %s월까지입니다." %(str(year), str(month-1)))
                    break
                    #jsonData를 출력하여 확인...........................................
            print(json.dumps(jsonData, indent = 4, sort_keys = True, ensure_ascii = False))

            natName = jsonData['response']['body']['items']['item']['natKorNm']
            natName = natName.replace(' ', '') #중국
            num = jsonData['response']['body']['items']['item']['num'] #인구
            ed = jsonData['response']['body']['items']['item']['ed'] #방한외래관광객
            print('[ %s_%s : %s ]' %(natName, yyyymm, num))
            print('------------------------------------------------------')
            jsonResult.append({'nat_name': natName, 'nat_cd': nat_cd,
                                 'yyyymm': yyyymm, 'visit_cnt': num})
            result.append([natName, nat_cd, yyyymm, num])
    return (jsonResult, result, natName, ed, dataEND)

# %%
# [code0] Main함수
jsonResult = []
result = []

print("<< 국내 입국한 외국인의 통계 데이터를 수집합니다. >>")
nat_cd = input('국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) : ')
nStartYear =int(input('데이터를 몇 년부터 수집할까요? : '))
nEndYear = int(input('데이터를 몇 년까지 수집할까요? : '))
ed_cd = "E"     #E : 방한외래관광객, D : 해외 출국

jsonResult, result, natName, ed, dataEND =getTourismStatsService(nat_cd,ed_cd, nStartYear, nEndYear) #[CODE 3]

if (natName=='') : #URL 요청은 성공하였지만, 데이터 제공이 안된 경우
        print('데이터가 전달되지 않았습니다. 공공데이터포털의 서비스 상태를 확인하기 바랍니다.')
else:
        #파일저장 1 : json 파일
        with open('./%s_%s_%d_%s.json' % (natName, ed, nStartYear, dataEND), 'w',
                    encoding='utf8') as outfile:
            jsonFile  = json.dumps(jsonResult, indent=4, sort_keys=True, ensure_ascii=False)
            outfile.write(jsonFile)
        #파일저장 2 : csv 파일
        columns = ["입국자국가", "국가코드", "입국연월", "입국자 수"]
        result_df = pd.DataFrame(result, columns = columns)
        result_df.to_csv('./%s_%s_%d_%s.csv' % (natName, ed, nStartYear, dataEND), index=False, encoding='cp949')

# jsonResult = []
# result = []
#
# print("<< 국내 입국한 외국인의 통계 데이터를 수집합니다. >>")
# nat_cd = input('국가 코드를 입력하세요(중국: 112 / 일본: 130 / 미국: 275) : ')
# nStartYear = int(input('데이터를 몇 년부터 수집할까요? : '))
# nEndYear = int(input('데이터를 몇 년까지 수집할까요? : '))
# ed_cd = "E" #E : 방한외래관광객, D : 해외 출국
# jsonResult, result, natName, ed, dataEND = getTourismStatsService(nat_cd, ed_cd, nStartYear, nEndYear) #[CODE 3]
#
# #파일저장 1 : json 파일
# with open('./%s_%s_%d_%s.json' % (natName, ed, nStartYear, dataEND),
#              'w', encoding = 'utf8') as outfile:
#     jsonFile = json.dumps(jsonResult, indent = 4, sort_keys = True,
#                                  ensure_ascii = False)
#     outfile.write(jsonFile)
# #파일저장 2 : csv 파일
# columns = ["입국자국가", "국가코드", "입국연월", "입국자 수"]
# result_df = pd.DataFrame(result, columns = columns)
# result_df.to_csv('./%s_%s_%d_%s.csv' % (natName, ed, nStartYear,
#                     dataEND), index=False, encoding='cp949')
# Out:
# << 국내 입국한 외국인의 통계 데이터를 수집합니다. >>
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201801&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.279975] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 305127,
#                     "rnum": 1,
#                     "ym": 201801
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201801 : 305127 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201802&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.333974] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 345341,
#                     "rnum": 1,
#                     "ym": 201802
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201802 : 345341 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201803&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.386900] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 403413,
#                     "rnum": 1,
#                     "ym": 201803
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201803 : 403413 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201804&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.440681] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 366604,
#                     "rnum": 1,
#                     "ym": 201804
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201804 : 366604 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201805&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.497295] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 370222,
#                     "rnum": 1,
#                     "ym": 201805
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201805 : 370222 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201806&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.558943] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 379891,
#                     "rnum": 1,
#                     "ym": 201806
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201806 : 379891 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201807&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.614427] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 410337,
#                     "rnum": 1,
#                     "ym": 201807
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201807 : 410337 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201808&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.674302] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 478140,
#                     "rnum": 1,
#                     "ym": 201808
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201808 : 478140 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201809&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.729706] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 434595,
#                     "rnum": 1,
#                     "ym": 201809
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201809 : 434595 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201810&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.779905] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 475307,
#                     "rnum": 1,
#                     "ym": 201810
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201810 : 475307 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201811&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.833462] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 404256,
#                     "rnum": 1,
#                     "ym": 201811
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201811 : 404256 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201812&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.890241] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 416279,
#                     "rnum": 1,
#                     "ym": 201812
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201812 : 416279 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201901&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:02.951648] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 392814,
#                     "rnum": 1,
#                     "ym": 201901
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201901 : 392814 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201902&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.006888] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 453379,
#                     "rnum": 1,
#                     "ym": 201902
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201902 : 453379 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201903&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.062409] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 487623,
#                     "rnum": 1,
#                     "ym": 201903
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201903 : 487623 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201904&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.120499] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 493250,
#                     "rnum": 1,
#                     "ym": 201904
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201904 : 493250 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201905&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.175920] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 500413,
#                     "rnum": 1,
#                     "ym": 201905
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201905 : 500413 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201906&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.229886] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 475007,
#                     "rnum": 1,
#                     "ym": 201906
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201906 : 475007 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201907&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.285085] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 519132,
#                     "rnum": 1,
#                     "ym": 201907
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201907 : 519132 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201908&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.341824] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 578112,
#                     "rnum": 1,
#                     "ym": 201908
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201908 : 578112 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201909&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.403078] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 541350,
#                     "rnum": 1,
#                     "ym": 201909
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201909 : 541350 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201910&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.475123] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 567695,
#                     "rnum": 1,
#                     "ym": 201910
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201910 : 567695 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201911&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.547644] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 505369,
#                     "rnum": 1,
#                     "ym": 201911
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201911 : 505369 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=201912&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.605995] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 508877,
#                     "rnum": 1,
#                     "ym": 201912
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_201912 : 508877 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202001&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.666153] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 481681,
#                     "rnum": 1,
#                     "ym": 202001
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202001 : 481681 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202002&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.725031] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 104086,
#                     "rnum": 1,
#                     "ym": 202002
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202002 : 104086 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202003&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.777134] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 16595,
#                     "rnum": 1,
#                     "ym": 202003
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202003 : 16595 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202004&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.829873] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 3935,
#                     "rnum": 1,
#                     "ym": 202004
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202004 : 3935 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202005&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.887628] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 5124,
#                     "rnum": 1,
#                     "ym": 202005
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202005 : 5124 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202006&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:03.944804] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 5051,
#                     "rnum": 1,
#                     "ym": 202006
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202006 : 5051 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202007&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.000545] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 9738,
#                     "rnum": 1,
#                     "ym": 202007
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202007 : 9738 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202008&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.057934] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 16275,
#                     "rnum": 1,
#                     "ym": 202008
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202008 : 16275 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202009&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.111413] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 15307,
#                     "rnum": 1,
#                     "ym": 202009
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202009 : 15307 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202010&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.163684] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 11477,
#                     "rnum": 1,
#                     "ym": 202010
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202010 : 11477 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202011&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.218311] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 9174,
#                     "rnum": 1,
#                     "ym": 202011
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202011 : 9174 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202012&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.275777] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 7987,
#                     "rnum": 1,
#                     "ym": 202012
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202012 : 7987 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202101&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.336712] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 7346,
#                     "rnum": 1,
#                     "ym": 202101
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202101 : 7346 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202102&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.395104] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 11982,
#                     "rnum": 1,
#                     "ym": 202102
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202102 : 11982 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202103&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.447874] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 18980,
#                     "rnum": 1,
#                     "ym": 202103
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202103 : 18980 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202104&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.506725] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 16830,
#                     "rnum": 1,
#                     "ym": 202104
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202104 : 16830 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202105&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.563077] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 14221,
#                     "rnum": 1,
#                     "ym": 202105
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202105 : 14221 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202106&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.622582] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 12942,
#                     "rnum": 1,
#                     "ym": 202106
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202106 : 12942 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202107&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.677817] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 13469,
#                     "rnum": 1,
#                     "ym": 202107
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202107 : 13469 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202108&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.732746] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 17103,
#                     "rnum": 1,
#                     "ym": 202108
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202108 : 17103 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202109&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.789213] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 19144,
#                     "rnum": 1,
#                     "ym": 202109
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202109 : 19144 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202110&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.844558] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 14035,
#                     "rnum": 1,
#                     "ym": 202110
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202110 : 14035 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202111&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.898168] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 12472,
#                     "rnum": 1,
#                     "ym": 202111
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202111 : 12472 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202112&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:04.955867] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 11691,
#                     "rnum": 1,
#                     "ym": 202112
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202112 : 11691 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202201&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:05.012954] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 9489,
#                     "rnum": 1,
#                     "ym": 202201
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202201 : 9489 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202202&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:05.071075] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 16752,
#                     "rnum": 1,
#                     "ym": 202202
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202202 : 16752 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202203&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:05.126431] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 14726,
#                     "rnum": 1,
#                     "ym": 202203
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202203 : 14726 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202204&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:05.180651] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 10230,
#                     "rnum": 1,
#                     "ym": 202204
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202204 : 10230 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202205&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:05.244837] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 11253,
#                     "rnum": 1,
#                     "ym": 202205
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202205 : 11253 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202206&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:05.299849] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 12741,
#                     "rnum": 1,
#                     "ym": 202206
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202206 : 12741 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202207&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:05.353889] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 17907,
#                     "rnum": 1,
#                     "ym": 202207
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202207 : 17907 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202208&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:05.411548] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 30248,
#                     "rnum": 1,
#                     "ym": 202208
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202208 : 30248 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202209&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:05.464497] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 29531,
#                     "rnum": 1,
#                     "ym": 202209
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202209 : 29531 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202210&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:05.520591] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 112,
#                     "natKorNm": "중  국",
#                     "num": 22940,
#                     "rnum": 1,
#                     "ym": 202210
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# [ 중국_202210 : 22940 ]
# ------------------------------------------------------
# http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList?_type=json&serviceKey=TEo5fURVg6O3ChvfXOmzkr0IXbTl0d4VkfIj3JVTz0ctJ%2BNS0IjPHxLXlijxDlubeXvzd3ZlGksTn%2FHhACp8gA%3D%3D&YM=202211&NAT_CD=112&ED_CD=E
# [2022-12-07 04:01:05.579398] Url Request Success
# 데이터 없음....
# 제공되는 통계 데이터는 2022년 10월까지입니다.
