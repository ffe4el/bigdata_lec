# %%
import pandas as pd

df = pd.read_csv("bank(1).csv")

#데이터의 행, 열 크기 확인
df.shape
# Out:
# (11162, 17)

# %%
# 전체 구조출력
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
#요약 통계 확인
df.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
df.head()
# df.tail()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %%
df['job'].unique() #종류들을 나열해줌
# Out:
# array(['admin.', 'technician', 'services', 'management', 'retired',
#        'blue-collar', 'unemployed', 'entrepreneur', 'housemaid',
#        'unknown', 'self-employed', 'student'], dtype=object)

# %%
df.job
# Out:
# 0             admin.
# 1             admin.
# 2         technician
# 3           services
# 4             admin.
#             ...
# 11157    blue-collar
# 11158       services
# 11159     technician
# 11160     technician
# 11161     technician
# Name: job, Length: 11162, dtype: object

# %%
df[['job', 'age']] #열값을 주르륵 보여줌
# Out:
#                job  age
# 0           admin.   59
# 1           admin.   56
# 2       technician   41
# 3         services   55
# 4           admin.   54
# ...            ...  ...
# 11157  blue-collar   33
# 11158     services   39
# 11159   technician   32
# 11160   technician   43
# 11161   technician   34
#
# [11162 rows x 2 columns]

# %%
df.loc[:,['job']] #job 열에 있는 모든 행[:}을 보여주는 코드
#loc은 전체 데이터 프레임에서 n번째 행, 혹은 n번째 열을 추출해주는 느낌
# Out:
#                job
# 0           admin.
# 1           admin.
# 2       technician
# 3         services
# 4           admin.
# ...            ...
# 11157  blue-collar
# 11158     services
# 11159   technician
# 11160   technician
# 11161   technician
#
# [11162 rows x 1 columns]

# %%
df.iloc[:,1] 
#iloc는 저체 데이터 프레임에서 n번째 행, 혹은 열에 있는 값을 추출(그래서 인덱스 제목이 표시가 안됨)
# Out:
# 0             admin.
# 1             admin.
# 2         technician
# 3           services
# 4             admin.
#             ...
# 11157    blue-collar
# 11158       services
# 11159     technician
# 11160     technician
# 11161     technician
# Name: job, Length: 11162, dtype: object

# %%
df[0:3] #행이 0부터 2까지 선택된다.
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes

# %%
df.iloc[0:3,:] #위랑 동일한 값이 출력된다.
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes

# %%
df.iloc[2] #2번째 있는 사람의 정보의 값을 추출해서 보여줌
# Out:
# age                  41
# job          technician
# marital         married
# education     secondary
# default              no
# balance            1270
# housing             yes
# loan                 no
# contact         unknown
# day                   5
# month               may
# duration           1389
# campaign              1
# pdays                -1
# previous              0
# poutcome        unknown
# deposit             yes
# Name: 2, dtype: object

# %%
df.iloc[0:3, 1:5] #[행, 열]
# Out:
#           job  marital  education default
# 0      admin.  married  secondary      no
# 1      admin.  married  secondary      no
# 2  technician  married  secondary      no

# %%
senior=df['age']>60
df[senior]
# Out:
#        age         job   marital  education default  balance housing loan  \
# 682     61     retired   married  secondary      no       77      no   no
# 813     61  management   married  secondary      no      985      no   no
# 1130    61  management   married   tertiary      no     6016      no   no
# 1142    68     retired  divorced    primary      no      250      no   no
# 1162    75     retired  divorced    primary      no     3881     yes   no
# ...    ...         ...       ...        ...     ...      ...     ...  ...
# 10651   67  management   married  secondary      no     1287      no   no
# 10721   73     retired   married    primary      no     1388      no   no
# 10731   74     retired   married  secondary      no     3771      no   no
# 10798   67  technician   married  secondary      no        0      no   no
# 10843   86     retired  divorced    unknown      no      157      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
vip = df['balance'] == df['balance'].max()
df[vip]
# Out:
#       age      job  marital  education default  balance housing loan  \
# 3043   84  retired  married  secondary      no    81204      no   no
# 3380   84  retired  married  secondary      no    81204      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 3043  telephone   28   dec       679         1    313         2    other
# 3380  telephone    1   apr       390         1     94         3  success
#
#      deposit
# 3043     yes
# 3380     yes

# %%
meeting = df['marital']='single'and df['age'] < 40
df[meeting]
# Out:
#        age          job  marital  education default  balance housing loan  \
# 8       37   technician     True  secondary      no        1     yes   no
# 9       28     services     True  secondary      no     5090     yes   no
# 10      38       admin.     True  secondary      no      100     yes   no
# 11      30  blue-collar     True  secondary      no      309     yes   no
# 12      29   management     True   tertiary      no      199     yes  yes
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11156   34  blue-collar     True  secondary      no      -72     yes   no
# 11157   33  blue-collar     True    primary      no        1     yes   no
# 11158   39     services     True  secondary      no      733      no   no
# 11159   32   technician     True  secondary      no       29      no   no
# 11161   34   technician     True  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
single = df['marital']=='single'
df[single]
# Out:
#        age          job marital  education default  balance housing loan  \
# 0       59       admin.  single  secondary      no     2343     yes   no
# 1       56       admin.  single  secondary      no       45      no   no
# 2       41   technician  single  secondary      no     1270     yes   no
# 3       55     services  single  secondary      no     2476     yes   no
# 4       54       admin.  single   tertiary      no      184      no   no
# ...    ...          ...     ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar  single    primary      no        1     yes   no
# 11158   39     services  single  secondary      no      733      no   no
# 11159   32   technician  single  secondary      no       29      no   no
# 11160   43   technician  single  secondary      no        0      no  yes
# 11161   34   technician  single  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
# 데이터 분석에 필요없는 칼럼 삭제하기
df = df.drop(['previous'], axis=1)
df
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays poutcome deposit
# ...

# %%
df1 = df.groupby('job').mean()
df1
# Out:
#                      age      balance        day    duration  campaign  \
# job
# admin.         39.374063  1195.866567  15.340330  347.929535  2.376312
# blue-collar    39.505144  1203.926440  15.235597  394.658951  2.541152
# entrepreneur   42.887195  1621.942073  15.442073  370.182927  2.725610
# housemaid      47.445255  1366.160584  16.364964  348.346715  2.689781
# management     40.218239  1793.663679  15.792284  361.482073  2.588075
# retired        65.424165  2417.250643  15.519280  389.993573  2.131105
# self-employed  39.809877  1865.372840  15.938272  396.155556  2.533333
# services       38.141928  1081.171181  15.728061  385.955580  2.576381
# student        26.102778  1500.783333  15.175000  330.672222  2.169444
# technician     39.001646  1556.294569  16.173341  363.791552  2.642348
# unemployed     40.997199  1314.719888  15.535014  422.843137  2.134454
# unknown        46.857143  1945.457143  15.457143  330.371429  2.785714
#
#                    pdays
# job
# ...

# %%
df2 = df.groupby('age').mean()
df2
# Out:
#          balance        day     duration   campaign      pdays
# age
# 18    237.000000  13.250000   202.625000   1.625000  33.750000
# 19    283.153846  13.076923   228.846154   1.923077  70.692308
# 20   1013.200000  16.150000   255.050000   2.000000  51.000000
# 21   1064.200000  13.900000   294.333333   1.966667  45.100000
# 22    844.979167  15.375000   260.125000   1.645833  59.770833
# ..           ...        ...          ...        ...        ...
# 89    553.000000  19.000000  2027.000000   5.000000  -1.000000
# 90    356.500000   8.000000   354.500000   2.000000  -1.000000
# 92    775.000000  24.000000   238.500000   3.500000  47.500000
# 93    775.000000  13.000000   668.000000   2.000000  95.000000
# 95   2282.000000  21.000000   207.000000  17.000000  -1.000000
#
# [76 rows x 5 columns]
